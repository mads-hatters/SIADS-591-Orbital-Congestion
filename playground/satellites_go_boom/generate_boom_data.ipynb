# %% [markdown]
# * 2 satellite TLEs right before collision
# * first TLE for all debris and satellite immediate after collision

# %% [markdown]
# FY-1C: 11 January 2007
#
# Iridium-33 + Cosmos-2251: February 10, 2009

# %%
import pandas as pd

# %%
path = f'../../../siads591 data/payload_all/2007-01-03T21_48_59.248512.csv'
columns = ['OBJECT_NAME', 'OBJECT_ID', 'EPOCH', 'MEAN_MOTION', 'ECCENTRICITY', 'INCLINATION', 'RA_OF_ASC_NODE', 'ARG_OF_PERICENTER', 'MEAN_ANOMALY', 'NORAD_CAT_ID', 'REV_AT_EPOCH', 'BSTAR', 'MEAN_MOTION_DOT', 'MEAN_MOTION_DDOT', 'SEMIMAJOR_AXIS', 'PERIOD', 'APOAPSIS', 'PERIAPSIS', 'OBJECT_TYPE', 'RCS_SIZE', 'COUNTRY_CODE', 'TLE_LINE0', 'TLE_LINE1', 'TLE_LINE2']

df = pd.read_csv(path)
df = df[(df.NORAD_CAT_ID == 25730)]
fy1c = df.loc[23006:24327].copy()
display(fy1c.T)
fy1c.to_pickle(f"./fy1c_before_after.pkl")
# Out:
#                                                                  23006  \
# CCSDS_OMM_VERS                                                       2
# COMMENT                              GENERATED VIA SPACE-TRACK.ORG API
# CREATION_DATE                                      2007-01-16T23:55:08
# ORIGINATOR                                                     18 SPCS
# OBJECT_NAME                                                 FENGYUN 1C
# OBJECT_ID                                                    1999-025A
# CENTER_NAME                                                      EARTH
# REF_FRAME                                                         TEME
# TIME_SYSTEM                                                        UTC
# MEAN_ELEMENT_THEORY                                               SGP4
# EPOCH                                       2007-01-11T21:44:56.546592
# MEAN_MOTION                                                    14.1182
# ECCENTRICITY                                                 0.0013513
# INCLINATION                                                    98.6464
# RA_OF_ASC_NODE                                                  1.7411
# ARG_OF_PERICENTER                                              266.036
# MEAN_ANOMALY                                                   94.0215
# EPHEMERIS_TYPE                                                       0
# CLASSIFICATION_TYPE                                                  U
# NORAD_CAT_ID                                                     25730
# ELEMENT_SET_NO                                                     999
# REV_AT_EPOCH                                                     39546
# BSTAR                                                       0.00012153
# MEAN_MOTION_DOT                                                1.8e-06
# MEAN_MOTION_DDOT                                                     0
# SEMIMAJOR_AXIS                                                 7231.29
# PERIOD                                                         101.995
# APOAPSIS                                                       862.927
# PERIAPSIS                                                      843.384
# OBJECT_TYPE                                                    PAYLOAD
# RCS_SIZE                                                         LARGE
# COUNTRY_CODE                                                       PRC
# LAUNCH_DATE                                                 1999-05-10
# SITE                                                               TSC
# DECAY_DATE                                                         NaN
# FILE                                                            352499
# GP_ID                                                         60158214
# TLE_LINE0                                                 0 FENGYUN 1C
# TLE_LINE1            1 25730U 99025A   07011.90621003  .00000180  0...
# TLE_LINE2            2 25730 098.6464 001.7411 0013513 266.0357 094...
#
#                                                                  24327
# CCSDS_OMM_VERS                                                       2
# COMMENT                              GENERATED VIA SPACE-TRACK.ORG API
# CREATION_DATE                                      2007-01-14T22:31:32
# ORIGINATOR                                                     18 SPCS
# OBJECT_NAME                                                 FENGYUN 1C
# OBJECT_ID                                                    1999-025A
# CENTER_NAME                                                      EARTH
# REF_FRAME                                                         TEME
# TIME_SYSTEM                                                        UTC
# MEAN_ELEMENT_THEORY                                               SGP4
# EPOCH                                       2007-01-12T13:03:23.730623
# MEAN_MOTION                                                    14.0657
# ECCENTRICITY                                                 0.0005047
# INCLINATION                                                    98.5902
# RA_OF_ASC_NODE                                                  2.0762
# ARG_OF_PERICENTER                                              97.3057
# MEAN_ANOMALY                                                   250.736
# EPHEMERIS_TYPE                                                       0
# CLASSIFICATION_TYPE                                                  U
# NORAD_CAT_ID                                                     25730
# ELEMENT_SET_NO                                                     999
# REV_AT_EPOCH                                                     39555
# BSTAR                                                      -0.00013794
# MEAN_MOTION_DOT                                               -2.7e-06
# MEAN_MOTION_DDOT                                                     0
# SEMIMAJOR_AXIS                                                 7249.27
# PERIOD                                                         102.376
# APOAPSIS                                                       874.799
# PERIAPSIS                                                      867.481
# OBJECT_TYPE                                                    PAYLOAD
# RCS_SIZE                                                         LARGE
# COUNTRY_CODE                                                       PRC
# LAUNCH_DATE                                                 1999-05-10
# SITE                                                               TSC
# DECAY_DATE                                                         NaN
# FILE                                                            351455
# GP_ID                                                         60133761
# TLE_LINE0                                                 0 FENGYUN 1C
# TLE_LINE1            1 25730U 99025A   07012.54402466 -.00000270  0...
# TLE_LINE2            2 25730 098.5902 002.0762 0005047 097.3057 250...

# %%
df = pd.read_csv("fy1c_deb_2007.csv")
df.groupby(by="NORAD_CAT_ID").first().to_pickle(f"./fy1c_deb_first_1324.pkl")
