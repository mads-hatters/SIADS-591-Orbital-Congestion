# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_pickle("../../../siads591 data/payload_maneuver_pkl/all.pkl")
df = df[df.NORAD_CAT_ID == 33053][['SEMIMAJOR_AXIS','INCLINATION']]
len(df)
# Out:
# 6326

# %%
df[1900:2350].plot(subplots=True,figsize=(10,10));
