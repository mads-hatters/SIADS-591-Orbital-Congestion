# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_pickle("../../data/maneuver/iss.pkl.gz","gzip")
df = df[~df.index.duplicated(keep='first')]
len(df)
# Out:
# 37040

# %% [markdown]
# * Only look at some columns.
# * Convert EPOCH to datetime
# * Set index to EPOCH

# %%
df = df[["MEAN_MOTION","ECCENTRICITY","INCLINATION","ARG_OF_PERICENTER","MEAN_ANOMALY",
    "BSTAR","MEAN_MOTION_DOT","SEMIMAJOR_AXIS","PERIOD","APOAPSIS","PERIAPSIS"]]
df
# Out:
#                             MEAN_MOTION  ECCENTRICITY  INCLINATION  \
# EPOCH
# 1998-11-20 06:49:59.999807    16.050648      0.012536    51.590801
# 1998-11-20 07:58:35.072831    16.049718      0.012341    51.617298
# 1998-11-20 10:57:42.787008    16.051344      0.012586    51.591400
# 1998-11-20 12:27:32.846687    16.050030      0.012386    51.595901
# 1998-11-20 13:57:13.741055    16.050746      0.012396    51.595100
# ...                                 ...           ...          ...
# 2021-01-17 17:27:41.618592    15.492969      0.000029    51.646599
# 2021-01-17 21:43:49.236672    15.492976      0.000030    51.646801
# 2021-01-18 02:31:18.949152    15.492980      0.000030    51.646801
# 2021-01-18 05:51:51.999840    15.492982      0.000030    51.646801
# 2021-01-18 10:10:30.423072    15.492994      0.000026    51.646702
#
#                             ARG_OF_PERICENTER  MEAN_ANOMALY     BSTAR  \
# EPOCH
# 1998-11-20 06:49:59.999807          86.418503    359.745392  0.000000
# 1998-11-20 07:58:35.072831          88.018700    273.493195  0.005735
# 1998-11-20 10:57:42.787008          91.342903    269.459808 -0.000018
# 1998-11-20 12:27:32.846687          87.817902    273.588989  0.000343
# 1998-11-20 13:57:13.741055          88.172699    273.342499  0.000302
# ...                                       ...           ...       ...
# 2021-01-17 17:27:41.618592         262.135986    269.878510  0.000015
# 2021-01-17 21:43:49.236672         263.406403    181.307297  0.000016
# 2021-01-18 02:31:18.949152         264.141388    214.846603  0.000016
# 2021-01-18 05:51:51.999840         264.654114    271.629303  0.000016
# 2021-01-18 10:10:30.423072         274.225494    184.500107  0.000018
#
#                             MEAN_MOTION_DOT  SEMIMAJOR_AXIS     PERIOD  \
# EPOCH
# 1998-11-20 06:49:59.999807        -0.000037     6638.557129  89.716003
# 1998-11-20 07:58:35.072831         0.118396     6638.813965  89.721001
# 1998-11-20 10:57:42.787008        -0.000433     6638.365234  89.711998
# 1998-11-20 12:27:32.846687         0.007131     6638.728027  89.719002
# 1998-11-20 13:57:13.741055         0.006326     6638.529785  89.714996
# ...                                     ...             ...        ...
# 2021-01-17 17:27:41.618592         0.000004     6796.917969  92.945000
# 2021-01-17 21:43:49.236672         0.000004     6796.916016  92.945000
# 2021-01-18 02:31:18.949152         0.000004     6796.915039  92.945000
# 2021-01-18 05:51:51.999840         0.000004     6796.914062  92.945000
# 2021-01-18 10:10:30.423072         0.000006     6796.911133  92.945000
#
#                               APOAPSIS   PERIAPSIS
# EPOCH
# 1998-11-20 06:49:59.999807  343.644012  177.199997
# 1998-11-20 07:58:35.072831  342.608002  178.748993
# 1998-11-20 10:57:42.787008  343.778992  176.681000
# 1998-11-20 12:27:32.846687  342.821014  178.365005
# 1998-11-20 13:57:13.741055  342.688995  178.100998
# ...                                ...         ...
# 2021-01-17 17:27:41.618592  418.977997  418.588989
# 2021-01-17 21:43:49.236672  418.984009  418.579010
# 2021-01-18 02:31:18.949152  418.983002  418.578003
# 2021-01-18 05:51:51.999840  418.981995  418.576996
# 2021-01-18 10:10:30.423072  418.953003  418.597992
#
# [37040 rows x 11 columns]

# %%
df[3000:5000].plot(subplots=True,figsize=(10,30));

# %%
# test = df[30000:32500].copy()
# test = test[['SEMIMAJOR_AXIS','INCLINATION']]
# test['SEMIMAJOR_AXIS_diff'] = test.SEMIMAJOR_AXIS.diff()
# test['SEMIMAJOR_AXIS_diff_both_sides'] = test.SEMIMAJOR_AXIS.diff() - test.SEMIMAJOR_AXIS.diff(-1)
# events = test[~test.SEMIMAJOR_AXIS_diff.between(-test['SEMIMAJOR_AXIS_diff'].std()*3,test['SEMIMAJOR_AXIS_diff'].std()*3)].dropna()



# fig, axs = plt.subplots(3, 1)
# test.SEMIMAJOR_AXIS.plot(ax=axs[0],figsize=(10,15))
# test['SEMIMAJOR_AXIS_diff'].plot(ax=axs[1])
# test['SEMIMAJOR_AXIS_diff_both_sides'].plot(ax=axs[2])
# # test.INCLINATION.plot(ax=axs[2])
# # test.INCLINATION.diff().plot(ax=axs[3])

# events

# %%
test = df[30000:32500].copy()
test = test[['SEMIMAJOR_AXIS','INCLINATION']]
test['SEMIMAJOR_AXIS_DIFF'] = test.SEMIMAJOR_AXIS.diff()
test['ROLLING'] = test.SEMIMAJOR_AXIS.rolling(5).median() # remove outliers
test['ROLLING_DIFF'] = test.ROLLING.diff()
std3 = test['ROLLING_DIFF'].std()*2
events = test[~test.ROLLING_DIFF.between(-std3,std3)].dropna()



fig, axs = plt.subplots(2, 1)
test.SEMIMAJOR_AXIS.plot(ax=axs[0],figsize=(10,8))
test['ROLLING'].plot(ax=axs[1])

events
# Out:
#                             SEMIMAJOR_AXIS  INCLINATION  SEMIMAJOR_AXIS_DIFF  \
# EPOCH
# 2016-08-24 14:20:23.866944     6782.345215    51.642799             0.011230
# 2016-09-10 18:46:28.398432     6783.832031    51.643200            -0.037109
# 2016-11-02 19:52:31.875744     6784.715820    51.645401            -0.107422
# 2017-03-02 21:26:59.383968     6782.854004    51.641499            -0.116211
# 2017-04-05 20:04:06.559392     6783.124023    51.644001            -0.009766
# 2017-04-29 21:32:03.672672     6783.391113    51.642101            -0.006836
# 2017-05-19 13:37:32.608992     6783.483887    51.640701            -0.055176
# 2017-08-10 04:55:45.266592     6782.751953    51.641300             0.035156
# 2017-08-27 19:42:08.930016     6783.254883    51.646702             0.239746
# 2017-08-27 21:17:09.451680     6783.295898    51.646301             0.041016
# 2017-09-28 05:34:52.052160     6783.175781    51.641998            -0.057129
# 2017-11-02 11:36:02.297088     6783.232910    51.642601             0.081055
# 2017-11-30 05:23:30.000192     6782.966797    51.641800            -0.228027
# 2018-01-20 12:35:06.660096     6782.651855    51.642399            -0.014160
# 2018-01-31 21:35:34.186272     6783.095215    51.641899             0.024414
# 2018-03-14 20:49:06.000384     6782.846191    51.638802            -0.032715
# 2018-04-18 19:22:33.858912     6782.748047    51.638100            -0.442871
# 2018-05-14 21:22:54.000192     6783.024902    51.639702             0.009766
# 2018-06-24 14:39:22.217184     6783.303223    51.638401             0.020996
#
#                                 ROLLING  ROLLING_DIFF
# EPOCH
# 2016-08-24 14:20:23.866944  6782.267090      2.217285
# 2016-09-10 18:46:28.398432  6783.832031      2.038086
# 2016-11-02 19:52:31.875744  6784.504883      2.495117
# 2017-03-02 21:26:59.383968  6782.785156      1.004395
# 2017-04-05 20:04:06.559392  6783.124023      0.827148
# 2017-04-29 21:32:03.672672  6783.391113      0.711914
# 2017-05-19 13:37:32.608992  6783.475098      0.330078
# 2017-08-10 04:55:45.266592  6782.716797      0.314941
# 2017-08-27 19:42:08.930016  6783.015137      0.416016
# 2017-08-27 21:17:09.451680  6783.254883      0.239746
# 2017-09-28 05:34:52.052160  6783.175781      0.723633
# 2017-11-02 11:36:02.297088  6783.146973      0.845215
# 2017-11-30 05:23:30.000192  6782.966797      0.505859
# 2018-01-20 12:35:06.660096  6782.601074      0.330078
# 2018-01-31 21:35:34.186272  6783.070801      0.552734
# 2018-03-14 20:49:06.000384  6782.846191      0.266113
# 2018-04-18 19:22:33.858912  6782.748047      0.351074
# 2018-05-14 21:22:54.000192  6782.955078      0.491211
# 2018-06-24 14:39:22.217184  6783.282227      0.674316

# %%
test = df[100:].copy()
test = test[['SEMIMAJOR_AXIS','INCLINATION']]
test['SEMIMAJOR_AXIS_DIFF'] = test.SEMIMAJOR_AXIS.diff()
test['ROLLING'] = test.SEMIMAJOR_AXIS.rolling(5).median()
test['ROLLING_DIFF'] = test.ROLLING.diff()
std3 = test['ROLLING_DIFF'].std()*2
events = test[~test.ROLLING_DIFF.between(-std3,std3)].dropna()



fig, axs = plt.subplots(2, 1)
test.SEMIMAJOR_AXIS.plot(ax=axs[0],figsize=(10,8))
test['ROLLING'].plot(ax=axs[1])

events
# Out:
#                             SEMIMAJOR_AXIS  INCLINATION  SEMIMAJOR_AXIS_DIFF  \
# EPOCH
# 1998-12-17 04:13:02.739360     6775.042969    51.592400            -0.085938
# 1998-12-21 23:45:31.900319     6778.191895    51.595901             0.332031
# 1999-06-03 19:15:41.819040     6770.419922    51.600300             0.052734
# 1999-10-27 05:00:36.071711     6752.214844    51.592098            -0.085938
# 1999-12-02 12:45:05.893343     6760.640137    51.591400            -0.062988
# ...                                    ...          ...                  ...
# 2020-07-04 11:10:47.000064     6797.288086    51.643002             0.085938
# 2020-07-12 12:36:17.356896     6796.263184    51.645699            -0.087891
# 2020-07-31 03:54:27.856224     6797.354980    51.643299            -0.223145
# 2020-09-11 13:04:09.007680     6797.901855    51.644402            -0.281250
# 2020-11-14 21:53:17.217312     6797.670898    51.645699            -0.033203
#
#                                 ROLLING  ROLLING_DIFF
# EPOCH
# 1998-12-17 04:13:02.739360  6775.024902      3.604004
# 1998-12-21 23:45:31.900319  6777.411133      2.787109
# 1999-06-03 19:15:41.819040  6770.367188      9.761230
# 1999-10-27 05:00:36.071711  6752.214844      1.434082
# 1999-12-02 12:45:05.893343  6760.640137     17.535156
# ...                                 ...           ...
# 2020-07-04 11:10:47.000064  6797.202148      0.815918
# 2020-07-12 12:36:17.356896  6796.351074     -0.834961
# 2020-07-31 03:54:27.856224  6797.354980      1.063965
# 2020-09-11 13:04:09.007680  6797.901855      0.738770
# 2020-11-14 21:53:17.217312  6797.670898      1.082031
#
# [235 rows x 5 columns]
