# %%
import pandas as pd
df = pd.read_pickle("./output/00337.pkl.gz","gzip")

# %%
df
# Out:
#                            EPOCH  NORAD_CAT_ID  MEAN_MOTION  ECCENTRICITY  \
# 0     2021-01-18T00:00:00.999648         47280    15.161319      0.001241
# 1     2021-01-18T00:00:00.999648         46782    15.627504      0.000261
# 2     2021-01-18T00:00:00.999648         47135    15.627016      0.000125
# 3     2021-01-18T00:00:00.999648         46783    15.627893      0.000243
# 4     2021-01-18T00:00:00.999648         46784    15.627509      0.000261
# ...                          ...           ...          ...           ...
# 1154  2021-01-18T16:27:49.301856         41240    12.809310      0.000736
# 1155  2021-01-18T16:35:15.137952         43689    14.214886      0.000352
# 1156  2021-01-18T16:38:13.870176         29499    14.214958      0.000127
# 1157  2021-01-18T16:41:17.716416         25991    14.164646      0.000944
# 1158  2021-01-18T16:56:00.468672         28054    14.136479      0.000712
#
#       INCLINATION  RA_OF_ASC_NODE  ARG_OF_PERICENTER  MEAN_ANOMALY  \
# 0         87.4473         28.8968           157.4971       30.6900
# 1         53.0540        102.3966            11.2655      242.0020
# 2         53.0544         88.3881            13.9797      226.5839
# 3         53.0540        102.4120           352.0254      258.6920
# 4         53.0541        102.4126            22.1243      227.9394
# ...           ...             ...                ...           ...
# 1154      66.0410        278.0950           272.0952       87.9220
# 1155      98.7089         81.2816            92.7554      267.4027
# 1156      98.4945         63.7771            70.4324       37.9642
# 1157      98.9983        358.0061           204.6916      328.2536
# 1158      98.9376          3.2917           340.8731      192.0716
#
#       REV_AT_EPOCH     BSTAR  MEAN_MOTION_DOT  MEAN_MOTION_DDOT  \
# 0              467 -0.079282    -1.405685e-02               0.0
# 1             1359  0.000363     3.280300e-04               0.0
# 2              925  0.000437     3.956400e-04               0.0
# 3             1360 -0.000754    -6.910000e-04               0.0
# 4             1354  0.000370     3.347200e-04               0.0
# ...            ...       ...              ...               ...
# 1154         23412  0.000091    -4.000000e-07               0.0
# 1155         11417  0.000017    -6.000000e-08               0.0
# 1156         73946  0.000015    -9.000000e-08               0.0
# 1157          9091 -0.000031    -1.070000e-06               0.0
# 1158         89030 -0.000016    -7.600000e-07               0.0
#
#       SEMIMAJOR_AXIS   PERIOD  APOAPSIS  PERIAPSIS
# 0           6895.681   94.978   526.103    508.989
# 1           6757.853   92.145   381.479    377.957
# 2           6757.993   92.148   380.701    379.016
# 3           6757.741   92.142   381.248    377.964
# 4           6757.851   92.145   381.480    377.953
# ...              ...      ...       ...        ...
# 1154        7715.865  112.418  1343.412   1332.049
# 1155        7198.459  101.302   822.858    817.791
# 1156        7198.435  101.301   821.212    819.388
# 1157        7215.470  101.661   844.147    830.524
# 1158        7225.052  101.864   852.059    841.775
#
# [1159 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['EPOCH', 'NORAD_CAT_ID', 'MEAN_MOTION', 'ECCENTRICITY', 'INCLINATION',
#        'RA_OF_ASC_NODE', 'ARG_OF_PERICENTER', 'MEAN_ANOMALY', 'REV_AT_EPOCH',
#        'BSTAR', 'MEAN_MOTION_DOT', 'MEAN_MOTION_DDOT', 'SEMIMAJOR_AXIS',
#        'PERIOD', 'APOAPSIS', 'PERIAPSIS'],
#       dtype='object')

# %%
df.dtypes
# Out:
# EPOCH                 object
# NORAD_CAT_ID           int64
# MEAN_MOTION          float64
# ECCENTRICITY         float64
# INCLINATION          float64
# RA_OF_ASC_NODE       float64
# ARG_OF_PERICENTER    float64
# MEAN_ANOMALY         float64
# REV_AT_EPOCH           int64
# BSTAR                float64
# MEAN_MOTION_DOT      float64
# MEAN_MOTION_DDOT     float64
# SEMIMAJOR_AXIS       float64
# PERIOD               float64
# APOAPSIS             float64
# PERIAPSIS            float64
# dtype: object

# %% [raw]
# EPOCH                 object -> datetime62[ns]
# NORAD_CAT_ID           int64 -> uint32
# MEAN_MOTION          float64 -> float64 (8 decimals)
# ECCENTRICITY         float64 -> float64
# INCLINATION          float64 -> float32 (4 decimals)
# RA_OF_ASC_NODE       float64 -> float32 (4 decimals)
# ARG_OF_PERICENTER    float64 -> float32 (4 decimals)
# MEAN_ANOMALY         float64 -> float32 (4 decimals)
# REV_AT_EPOCH           int64 -> uint32
# BSTAR                float64 -> float64
# MEAN_MOTION_DOT      float64 -> float64
# MEAN_MOTION_DDOT     float64 -> float64
# SEMIMAJOR_AXIS       float64 -> float32 (4 decimals)
# PERIOD               float64 -> float32 (4 decimals)
# APOAPSIS             float64 -> float32 (4 decimals)
# PERIAPSIS            float64 -> float32 (4 decimals)
#
# Drop these?
# MEAN_ANOMALY         float64 -> float32 (4 decimals)
# REV_AT_EPOCH           int64 -> uint32
# BSTAR                float64 -> float64
# MEAN_MOTION_DOT      float64 -> float64
# MEAN_MOTION_DDOT     float64 -> float64
# PERIOD               float64 -> float32 (4 decimals)

# %%
import numpy as np
np.datetime64('now').astype(object).year
# Out:
# int
