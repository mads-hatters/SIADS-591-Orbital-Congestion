# %% [raw]
# EPOCH                 object -> datetime64[ns]
# NORAD_CAT_ID           int64 -> uint32
# MEAN_MOTION          float64 -> float64 (8 decimals)
# ECCENTRICITY         float64 -> float64
# INCLINATION          float64 -> float32 (4 decimals)
# RA_OF_ASC_NODE       float64 -> float32 (4 decimals)
# ARG_OF_PERICENTER    float64 -> float32 (4 decimals)
# MEAN_ANOMALY         float64 -> float32 (4 decimals)
# REV_AT_EPOCH           int64 -> uint32
# BSTAR                float64 -> float64
# MEAN_MOTION_DOT      float64 -> float64
# MEAN_MOTION_DDOT     float64 -> float64
# SEMIMAJOR_AXIS       float64 -> float32 (4 decimals)
# PERIOD               float64 -> float32 (4 decimals)
# APOAPSIS             float64 -> float32 (4 decimals)
# PERIAPSIS            float64 -> float32 (4 decimals)
#
# Drop these?
# MEAN_ANOMALY         float64 -> float32 (4 decimals)
# REV_AT_EPOCH           int64 -> uint32
# BSTAR                float64 -> float64
# MEAN_MOTION_DOT      float64 -> float64
# MEAN_MOTION_DDOT     float64 -> float64
# PERIOD               float64 -> float32 (4 decimals)

# %%
import pandas as pd
import numpy as np

columns = ['EPOCH', 'NORAD_CAT_ID', 'MEAN_MOTION', 'ECCENTRICITY', 'INCLINATION', 'RA_OF_ASC_NODE', 'ARG_OF_PERICENTER', 'MEAN_ANOMALY', 'REV_AT_EPOCH', 'BSTAR', 'MEAN_MOTION_DOT', 'MEAN_MOTION_DDOT', 'SEMIMAJOR_AXIS', 'PERIOD', 'APOAPSIS', 'PERIAPSIS']
# df = pd.read_csv("./tmp/pre1970.csv")
# df[columns].to_pickle('./output/00000.pkl.gz',"gzip")

# dtypes = {'NORAD_CAT_ID':np.uint32,
#           'REV_AT_EPOCH':np.uint32,
#           'INCLINATION':np.float32,
#           'RA_OF_ASC_NODE':np.float32,
#           'ARG_OF_PERICENTER':np.float32,
#           'MEAN_ANOMALY':np.float32,
#           'SEMIMAJOR_AXIS':np.float32,
#           'PERIOD':np.float32,
#           'APOAPSIS':np.float32,
#           'PERIAPSIS':np.float32,
#           'MEAN_MOTION':np.float64,
#           'ECCENTRICITY':np.float64,
#           'BSTAR':np.float64,
#           'MEAN_MOTION_DOT':np.float64,
#           'MEAN_MOTION_DDOT':np.float64,
#          }
# df = pd.read_csv("./tmp/pre1970.csv",
#                  usecols=columns,
#                  parse_dates=['EPOCH'],
#                  infer_datetime_format=True,
#                  index_col='EPOCH',
#                  dtype=dtypes,
#                 )
# df.info()
# df = pd.read_pickle("./output/00109.pkl.gz","gzip")

# %%
logs = pd.read_pickle("./logs.pkl.gz","gzip")
logs
# Out:
#               created_on              type  \
# 0    2021-01-18 19:21:35             login
# 1    2021-01-18 19:25:30        fetch_init
# 2    2021-01-18 19:25:46     fetch_success
# 3    2021-01-18 19:25:47  process_complete
# 4    2021-01-18 19:25:47        fetch_init
# ...                  ...               ...
# 1271 2021-01-18 23:45:34  process_complete
# 1272 2021-01-18 23:45:34        fetch_init
# 1273 2021-01-18 23:46:00     fetch_success
# 1274 2021-01-18 23:46:04  process_complete
# 1275 2021-01-18 23:46:04        fetch_init
#
#                                                     url  \
# 0                                                  None
# 1     https://www.space-track.org/basicspacedata/que...
# 2     https://www.space-track.org/basicspacedata/que...
# 3     https://www.space-track.org/basicspacedata/que...
# 4     https://www.space-track.org/basicspacedata/que...
# ...                                                 ...
# ...

# %%
df
