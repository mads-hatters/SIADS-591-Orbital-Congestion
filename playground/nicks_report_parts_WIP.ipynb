# %% [markdown]
# A dashboard was created to summarize and present, in an accessible way, some of the complex visuals created by the team.
#
# The dashboard can be accessed either online via Heroku or by runing the below script.  Both options use the same source code and data sources.
#
# [oc-dash.herokuapp.com/](https://oc-dash.herokuapp.com/)
#
# NOTE: do to resource limitations on the free version of Heroku, please limit the filtering to one week or less of data.

# %%
import os
os.chdir('../dashboard')
exec(open('./app.py').read())
os.chdir('..')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %%
import pandas as pd
pd.read_csv('../data/socrates/socrates_20201209042013.csv.gz').head()
# Out:
#    sat1_norad          sat1_name  sat1_days_epoch  max_prob  dil_thr_km  \
# 0       44421    COSMOS 2535 [+]            0.842  0.047080       0.002
# 1       14452    METEOR 2-10 [?]            3.946  0.005832       0.038
# 2       26113          IMAGE [P]            9.650  0.003850       2.112
# 3       14452    METEOR 2-10 [?]            3.876  0.002003       0.066
# 4       40935  LEMUR-2-PETER [+]            5.177  0.001938       0.012
#
#    min_rng_km  rel_velo_kms  sat2_norad          sat2_name  sat2_days_epoch  \
# 0       0.009         0.000       44424    COSMOS 2536 [+]            0.842
# 1       0.055        14.803       41302    NOAA 16 DEB [-]            3.780
# 2       4.014        16.806       45381  STARLINK-1258 [+]            7.375
# 3       0.093        14.804       41302    NOAA 16 DEB [-]            3.710
# 4       0.044         8.494       39842      SL-16 DEB [-]            7.270
#
#                  start_time                  tca_time  \
# 0  2020 Dec 09 00:00:00.000  2020 Dec 09 00:03:06.880
# 1  2020 Dec 12 03:23:20.510  2020 Dec 12 03:23:20.848
# 2  2020 Dec 15 20:01:51.336  2020 Dec 15 20:01:51.513
# 3  2020 Dec 12 01:41:42.891  2020 Dec 12 01:41:43.228
# 4  2020 Dec 13 13:05:04.536  2020 Dec 13 13:05:05.125
#
#                   stop_time extract_sort                extract_date
# 0  2020 Dec 16 00:00:00.000      MAXPROB  2020-12-09 04:20:13.634745
# 1  2020 Dec 12 03:23:21.186      MAXPROB  2020-12-09 04:20:13.634745
# 2  2020 Dec 15 20:01:51.690      MAXPROB  2020-12-09 04:20:13.634745
# 3  2020 Dec 12 01:41:43.566      MAXPROB  2020-12-09 04:20:13.634745
# 4  2020 Dec 13 13:05:05.713      MAXPROB  2020-12-09 04:20:13.634745
