# %% [markdown]
# ## Running the Dashboard
#
# **NOTE** - While running, the app will never come back so the only way to stop it is to interrupt the kernal.

# %%
import oc_dash_load

gpd_df = oc_dash_load.load_satellite_data()
tle_df = oc_dash_load.load_intercept_data()

gpd_df.to_pickle('./data/satellite_data.pkl.gz')
tle_df.to_pickle('./data/intercept_data.pkl.gz')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 85/85 [00:04<00:00, 19.70it/s]

# %%
exec(open('./app.py').read())
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %%
import pandas as pd
df = pd.read_pickle('./data/satellite_data.pkl.gz')
df
# Out:
#        Unnamed: 0  CCSDS_OMM_VERS                            COMMENT  \
# 0               0             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 1               1             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 2               2             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 3               3             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 4               4             2.0  GENERATED VIA SPACE-TRACK.ORG API
# ...           ...             ...                                ...
# 46166       46166             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 46167       46167             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 46168       46168             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 46169       46169             2.0  GENERATED VIA SPACE-TRACK.ORG API
# 46170       46170             2.0  GENERATED VIA SPACE-TRACK.ORG API
#
#              CREATION_DATE ORIGINATOR           OBJECT_NAME  OBJECT_ID  \
# 0      2021-01-27T18:14:09    18 SPCS  TBA - TO BE ASSIGNED        NaN
# 1      2021-01-23T18:01:02    18 SPCS  TBA - TO BE ASSIGNED        NaN
# 2      2021-01-26T02:30:00    18 SPCS  TBA - TO BE ASSIGNED        NaN
# 3      2021-01-28T20:49:41    18 SPCS  TBA - TO BE ASSIGNED        NaN
# 4      2021-01-28T20:49:41    18 SPCS  TBA - TO BE ASSIGNED        NaN
# ...                    ...        ...                   ...        ...
# 46166  2021-01-29T02:31:30    18 SPCS            VANGUARD 2  1959-001A
# 46167  2004-08-15T23:35:20    18 SPCS            EXPLORER 4  1958-005A
# 46168  2004-08-15T23:35:23    18 SPCS             SPUTNIK 3  1958-004B
# 46169  2021-01-29T02:31:30    18 SPCS            VANGUARD 1  1958-002B
# 46170  2004-08-15T23:37:47    18 SPCS            EXPLORER 1  1958-001A
#
#       CENTER_NAME REF_FRAME TIME_SYSTEM  ...  \
# 0           EARTH      TEME         UTC  ...
# 1           EARTH      TEME         UTC  ...
# 2           EARTH      TEME         UTC  ...
# 3           EARTH      TEME         UTC  ...
# 4           EARTH      TEME         UTC  ...
# ...           ...       ...         ...  ...
# 46166       EARTH      TEME         UTC  ...
# 46167       EARTH      TEME         UTC  ...
# 46168       EARTH      TEME         UTC  ...
# 46169       EARTH      TEME         UTC  ...
# 46170       EARTH      TEME         UTC  ...
#
#                                                TLE_LINE1  \
# 0                           NO TLE FORMAT AVAILABLE 9997
# 1                           NO TLE FORMAT AVAILABLE 9997
# 2                           NO TLE FORMAT AVAILABLE 9997
# 3                           NO TLE FORMAT AVAILABLE 9997
# 4                           NO TLE FORMAT AVAILABLE 9997
# ...                                                  ...
# 46166  1 00011U 59001A   21028.98087371  .00000350  0...
# 46167  1 00009U 58005  A 59275.28696823  .00892850 +0...
# 46168  1 00008U 58004  B 60095.16166626  .02607090 +0...
# 46169  1 00005U 58002B   21028.73556114 -.00000069  0...
# 46170  1 00004U 58001  A 70090.03500497  .07718844 +0...
#
#                                                TLE_LINE2            x  \
# 0                                NO TLE FORMAT AVAILABLE          NaN
# 1                                NO TLE FORMAT AVAILABLE          NaN
# 2                                NO TLE FORMAT AVAILABLE          NaN
# 3                                NO TLE FORMAT AVAILABLE          NaN
# 4                                NO TLE FORMAT AVAILABLE          NaN
# ...                                                  ...          ...
# 46166  2 00011  32.8668 288.6594 1467457  84.7071 291...   385.355217
# 46167  2 00009 050.2549 082.4216 0254534 057.7226 303... -4413.283233
# 46168  2 00008 065.0599 163.5585 0088318 135.6760 224... -6265.543004
# 46169  2 00005  34.2573 254.2361 1847896 286.1633  54...  8621.926636
# 46170  2 00004 033.1468 334.6171 0024739 311.5310 048... -4653.724454
#
#                  y            z           RCS_SIZE_NAME  \
# 0              NaN          NaN                 Unknown
# 1              NaN          NaN                 Unknown
# 2              NaN          NaN                 Unknown
# 3              NaN          NaN                 Unknown
# 4              NaN          NaN                 Unknown
# ...            ...          ...                     ...
# 46166 -8110.909680 -1332.862233  Medium (0.1m^2 - 1m^2)
# 46167   704.435305  5043.202916                 Unknown
# 46168 -1933.072760  -272.258735           Large (>1m^2)
# 46169  1100.013418  5345.627494  Medium (0.1m^2 - 1m^2)
# 46170  3362.570723 -3207.995261                 Unknown
#
#                                              description  allsat_marker_size  \
# 0      \n               <p>\n               Name: TBA...                   4
# 1      \n               <p>\n               Name: TBA...                   4
# 2      \n               <p>\n               Name: TBA...                   4
# 3      \n               <p>\n               Name: TBA...                   4
# 4      \n               <p>\n               Name: TBA...                   4
# ...                                                  ...                 ...
# 46166  \n               <p>\n               Name: VAN...                   4
# 46167  \n               <p>\n               Name: EXP...                   4
# 46168  \n               <p>\n               Name: SPU...                   5
# 46169  \n               <p>\n               Name: VAN...                   4
# 46170  \n               <p>\n               Name: EXP...                   4
#
#            country                                        allsat_text
# 0          Unknown  <b>Name</b>: TBA - TO BE ASSIGNED<br><b>Countr...
# 1          Unknown  <b>Name</b>: TBA - TO BE ASSIGNED<br><b>Countr...
# 2          Unknown  <b>Name</b>: TBA - TO BE ASSIGNED<br><b>Countr...
# 3          Unknown  <b>Name</b>: TBA - TO BE ASSIGNED<br><b>Countr...
# 4          Unknown  <b>Name</b>: TBA - TO BE ASSIGNED<br><b>Countr...
# ...            ...                                                ...
# 46166          USA  <b>Name</b>: VANGUARD 2<br><b>Country</b>: USA...
# 46167          USA  <b>Name</b>: EXPLORER 4<br><b>Country</b>: USA...
# 46168  Former USSR  <b>Name</b>: SPUTNIK 3<br><b>Country</b>: Form...
# 46169          USA  <b>Name</b>: VANGUARD 1<br><b>Country</b>: USA...
# 46170          USA  <b>Name</b>: EXPLORER 1<br><b>Country</b>: USA...
#
# [46171 rows x 49 columns]

# %%
# Out:
#     OBJECT_TYPE  year  Count
# 0        DEBRIS  1958      2
# 1        DEBRIS  1959      5
# 2        DEBRIS  1960     36
# 3        DEBRIS  1961    378
# 4        DEBRIS  1962    489
# ..          ...   ...    ...
# 123     PAYLOAD  2017   7489
# 124     PAYLOAD  2018   7858
# 125     PAYLOAD  2019   8266
# 126     PAYLOAD  2020   9459
# 127     PAYLOAD  2021   9460
#
# [128 rows x 3 columns]

# %%
# Out:
#     OBJECT_TYPE  year  Count
# 0        DEBRIS  1960     10
# 1        DEBRIS  1961     43
# 2        DEBRIS  1962    122
# 3        DEBRIS  1963    167
# 4        DEBRIS  1964    229
# ..          ...   ...    ...
# 120     PAYLOAD  2017   3064
# 121     PAYLOAD  2018   3176
# 122     PAYLOAD  2019   3259
# 123     PAYLOAD  2020   3370
# 124     PAYLOAD  2021   3374
#
# [125 rows x 3 columns]
